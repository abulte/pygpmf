# %%
import gpmf

# %%
stream = gpmf.io.extract_gpmf_stream("../pytube-server/data/2021-07-04/GX010103.MP4")

# %%
plotter = gpmf.gps_plot.GPSPlotter(stream)

# %%
plotter.plot()

# %%
plotter.get_bounding_box()
# Out:
# {'minx': 2.0582384, 'miny': 48.9786595, 'maxx': 2.0599573, 'maxy': 48.9803557}
